# %% [markdown]
# # SimCenter Programming Bootcamp: Web scrabbing using python
#
# ## by Wael Elhaddad
# (ported to jupyter notebooks by Peter Mackenzie-Helnwein)
#
# University of California at Berkeley, CA, United States

# %% [markdown]
# ## Part 1: Session opening by Wael Elhaddad
# **Start this session** by watching the first 30 minutes of https://youtu.be/VH-slcnmTJc

# %% [markdown]
# ## Part 2: "Request"

# %% [markdown]
# Loading the supporting modules

# %%
import requests

# %%
#Let's request the tall buildings information
response = requests.get("https://data.sfgov.org/resource/5kya-mfst.json")

# %%
#Let's check the response is OK (return code 200)
if(response.status_code == 200):
    #We will convert the response to json 
    tallBuildings = response.json()
    
    #we will read the first building in the response and print some information
    building = tallBuildings[0]
    print("Building Name", ["name"])
    print("\tOccupancy: ", building["occupancy"])
    print("\tAddress: ", building["address"])
# Out:
# Building Name ['name']
# 	Occupancy:  Residential
# 	Address:  450 Folsom Street

# %% [markdown]
# ### Excercise 1: Print to the screen the list of buildings
#
# including relevant information about the building like
# * structure type
# * occupancy,
# * number of stories,
# * total area.

# %%
tallBuildings[0]
# Out:
# {'objectid': '333',
#  'polygon': {'type': 'Polygon',
#   'coordinates': [[[-122.394933364, 37.78782009],
#     [-122.39448986899998, 37.78746519],
#     [-122.39405427, 37.787809283],
#     [-122.393814643, 37.787998569],
#     [-122.39424619099998, 37.788342877],
#     [-122.394269178, 37.788337776],
#     [-122.394768492, 37.787943353],
#     [-122.394772886, 37.787946857],
#     [-122.394933364, 37.78782009]]]},
#  'name': '450 Folsom [Transbay Block 8]',
#  'address': '450 Folsom Street',
#  'mapblocklot': '3737042',
#  'mbl_unique': '3737042',
#  'date': '2019',
#  'height_ft': '550',
#  'stories_below_grade': '2',
#  'occupancy': 'Residential',
#  'structural_types': 'Unknown',
#  'facade_material': 'glass',
#  'foundation_system': 'Mat',
#  'liquefaction_potential': 'Very High',
#  'bedrockdepth_mean': '104',
#  'bedrockdepth_max': '138',
#  'bedrockdepth_min': '68',
#  'completion_date': '2019',
#  'collected_on': '2018-07-06T00:00:00.000',
#  'primary_source': 'Peer Reviewers',
#  'shape_length': '0.0028505426397520085',
#  'shape_area': '4.7227164433822106E-7'}

# %%
for building in tallBuildings:
    print("Building Name", ["name"])
    print("\tStructure type: ", building["structural_types"])
    print("\tOccupancy: ", building["occupancy"])
    print("\tAddress: ", building["address"])
    print("\tArea: ", building["shape_area"])
# Out:
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Residential
# 	Address:  450 Folsom Street
# 	Area:  4.7227164433822106E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  250 Howard Street
# 	Area:  2.685865008365523E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  33 Tehama Street
# 	Area:  1.8332720773302768E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  340 Fremont Street
# 	Area:  1.9986015611898653E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  526 Mission Street
# 	Area:  1.3428554857703483E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  350 Mission Street
# 	Area:  1.6967575321855257E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  50 1st Street
# 	Area:  2.0143561585045153E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  299 Fremont Street
# 	Area:  1.1954305375707647E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  160 Folsom Street
# 	Area:  3.443832882179721E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1500 Mission Street
# 	Area:  4.3928190691860594E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  415 Mission Street
# 	Area:  3.321302115970703E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  33 8th Street
# 	Area:  6.999255387555566E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1500 Mission Street
# 	Area:  5.032454561630007E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  181 Fremont Street
# 	Area:  1.4003349039844993E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  500 Folsom Street
# 	Area:  9.503497558800389E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  350 Bush Street
# 	Area:  2.980074880802184E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  399 Fremont Street
# 	Area:  3.4037245901625376E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  222 2nd Street
# 	Area:  1.9343890784023564E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1411 Market Street
# 	Area:  1.6710496001128047E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  535 Mission Street
# 	Area:  1.3334140396374518E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  55 9th Street
# 	Area:  1.613446937955284E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  45 Lansing Street
# 	Area:  1.3243064835828072E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  1190 Mission Street
# 	Area:  1.2484904354408828E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  338 Main Street
# 	Area:  1.0720160690621855E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  301 Beale Street
# 	Area:  1.4490250759814973E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  525 Golden Gate Avenue
# 	Area:  1.8871946817826863E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  425 1st Street
# 	Area:  1.4984675089238934E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1 Hawthorne Street
# 	Area:  9.29055921046105E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  706 Mission Street
# 	Area:  1.1067565200428706E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1188 Mission Street
# 	Area:  1.2831672123831753E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  301 Mission Street
# 	Area:  1.3981203012059514E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  555 Mission Street
# 	Area:  1.931241112847632E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  888 Howard Street
# 	Area:  3.1211877032338003E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  125 3rd Street
# 	Area:  2.6957525874424297E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  401 Harrison Street
# 	Area:  1.0510882954484564E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  301 Main Street
# 	Area:  1.1043124955662576E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  338 Spear Street
# 	Area:  9.891186353343393E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  355 1st Street
# 	Area:  9.97523886780194E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  680 Mission Street
# 	Area:  2.8096829083310603E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  501 Beale Street
# 	Area:  1.9551662544656136E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  400 Beale Street
# 	Area:  1.6650269444366481E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  388 Beale Street
# 	Area:  2.831880099729324E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  55 2nd Street
# 	Area:  1.899033945392721E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  2 Folsom Street
# 	Area:  6.244049051840741E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  560 Mission Street
# 	Area:  1.8189381256559067E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  33 New Montgomery Street
# 	Area:  1.1684837541574792E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  150 California Street
# 	Area:  1.260267530351649E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  101 2nd Street
# 	Area:  2.351850992447883E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  181 3rd Street
# 	Area:  1.7558717147652515E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  199 Fremont Street
# 	Area:  1.9240978674398314E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  757 Market Street
# 	Area:  4.351439331965634E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Residential
# 	Address:  235 Pine Street
# 	Area:  8.207196190527492E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  160 Spear Street
# 	Area:  1.3293249855544688E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  505 Montgomery Street
# 	Area:  1.3123936595474634E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  600 California Street
# 	Area:  1.2432091603184066E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  121 Spear Street
# 	Area:  4.840196149648995E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  135 Main Street
# 	Area:  1.1785839131206475E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  333 Battery Street
# 	Area:  1.3622013344484767E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  201 Spear Street
# 	Area:  1.4913963357761182E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  345 Spear Street
# 	Area:  6.473203140882416E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  55 4th Street
# 	Area:  8.6156208996646E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  275 Battery Street
# 	Area:  1.446910787962535E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 First Street
# 	Area:  1.938340547351819E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  301 Howard Street
# 	Area:  1.3345600615562875E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  123 Mission Street
# 	Area:  1.2094462461248867E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  75 Hawthorne Street
# 	Area:  1.991339606022656E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  222 Mason Street
# 	Area:  2.651155476120261E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  88 Kearny Street
# 	Area:  9.298948704582825E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  333 Bush Street
# 	Area:  1.5437523590830602E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  71 Stevenson Street
# 	Area:  1.8725381010441978E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  388 Market Street
# 	Area:  1.2667874982181088E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  455 Market Street
# 	Area:  1.3003863178237228E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  345 California Street
# 	Area:  3.31426836548957E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  555 Montgomery Street
# 	Area:  1.2019369064353893E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 Spear Street
# 	Area:  9.639706656909211E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  55 Cyril Magnin Street
# 	Area:  3.682803292825282E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  50 3rd Street
# 	Area:  3.1786102479609463E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  150 Spear Street
# 	Area:  1.3587066341954612E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  50 Fremont Street
# 	Area:  1.8625867633294892E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 Sansome Street
# 	Area:  1.3190818017174221E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  456 Montgomery Street
# 	Area:  9.981970940983695E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1275 Market Street
# 	Area:  2.7958346339499363E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  655 Montgomery Street
# 	Area:  1.3818099260334245E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  353 Sacramento Street
# 	Area:  1.3587979005343473E-7
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  201 Mission Street
# 	Area:  3.487659318002226E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  25 Jessie Street
# 	Area:  5.2611601596978455E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  101 Montgomery Street
# 	Area:  8.220361404772773E-8
# Building Name ['name']
# 	Structure type:  Steel Braced Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  580 California Street
# 	Area:  1.408410542838294E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  101 California Street
# 	Area:  3.9384008407256386E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  601 Montgomery Street
# 	Area:  1.2282759580622158E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  505 Sansome Street
# 	Area:  8.629416699404525E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  120 Kearny Street
# 	Area:  1.7745654942281868E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  150 Drumm Street
# 	Area:  3.015800146258735E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  444 Market Street
# 	Area:  1.969686399525818E-7
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  45 Fremont Street
# 	Area:  1.67441866698547E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  180 Montgomery Street
# 	Area:  1.1169840503996095E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  350 California Street
# 	Area:  1.4221343302463692E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  333 Market Street
# 	Area:  1.7065308262210337E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  595 Market Street
# 	Area:  1.7191099719608974E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  1 Market Street
# 	Area:  1.7889916713335098E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1455 Market Street
# 	Area:  0.0000011219131700676664
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  1 Market Street
# 	Area:  1.2429019462237974E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  5 The Embarcadero
# 	Area:  7.011588051368206E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  1500 Van Ness Avenue
# 	Area:  2.661911907641997E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  480 Sutter Street
# 	Area:  1.6075274263286157E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 Van Ness Avenue
# 	Area:  1.3067822554907531E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (Without Residential)
# 	Address:  425 Market Street
# 	Area:  2.499062539769695E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  600 Montgomery Street
# 	Area:  2.849049138898934E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 Pine Street
# 	Area:  1.2083157313930462E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  525 Market Street
# 	Area:  2.5609550995314626E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  575 Market Street
# 	Area:  1.120883550434168E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  50 California Street
# 	Area:  2.183880580595598E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  611 Folsom Street
# 	Area:  2.1552687937969759E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  201 Clay Street
# 	Area:  2.659410175144267E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  750 Kearny Street
# 	Area:  2.11549228721169E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  330 Taylor Street
# 	Area:  8.0808784679356E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  101 Clay Street
# 	Area:  2.262390387574792E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  77 Beale Street
# 	Area:  2.3291569665487969E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  400 California Street
# 	Area:  9.706115027841719E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  345 Stockton Street
# 	Area:  1.0747431407538941E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  555 California Street
# 	Area:  2.682591069796755E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  475 Sansome Street
# 	Area:  1.9109936483650486E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  335 Powell Street
# 	Area:  1.4543061214468267E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 Post Street
# 	Area:  1.074076493866176E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  301 Clay Street
# 	Area:  1.833493366679055E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  425 California Street
# 	Area:  5.7640839990631017E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  999 Green Street
# 	Area:  1.218798402404097E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  50 Beale Street
# 	Area:  2.63424843995705E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  1400 Geary Blvd
# 	Area:  8.240165495648007E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  450 Sansome Street
# 	Area:  7.491051612407191E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  180 Sansome Street
# 	Area:  7.863189063431661E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 California Street
# 	Area:  1.6883258883288588E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  555 Pine Street
# 	Area:  1.770627047487484E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1050 North Point Street
# 	Area:  7.501581748111473E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1000 North Point Street
# 	Area:  7.671560514895911E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  300 Clay Street
# 	Area:  2.689445760148343E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1750 Taylor Street
# 	Area:  1.6702230038910086E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  44 Montgomery Street
# 	Area:  1.610585217474994E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  10 Miller Place
# 	Area:  4.202304656949178E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  555 Market Street
# 	Area:  1.9215255222331206E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1200 Gough Street
# 	Area:  6.316574949375869E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  650 California Street
# 	Area:  1.419775935890491E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Mixed Uses (With Residential)
# 	Address:  1390 Market Street
# 	Area:  1.6255506416508988E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  1070 Green Street
# 	Area:  6.128827523079003E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Residential
# 	Address:  2200 Sacramento Street
# 	Area:  1.106389877597409E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  1170 Sacramento Street
# 	Area:  8.354937324784105E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  680 Folsom Street
# 	Area:  2.703808150082878E-7
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  950 Mason Street
# 	Area:  8.731151359987368E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  111 Pine Street
# 	Area:  1.0681890019112448E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  1200 California Street
# 	Area:  9.88108037532309E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  405 Davis Court
# 	Area:  7.607709576698198E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Residential
# 	Address:  155 Jackson Street
# 	Area:  7.608215056246246E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  601 California Street
# 	Area:  1.229045085963234E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  201 Mason Street
# 	Area:  5.016127022309057E-7
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  450 Golden Gate Avenue
# 	Area:  5.79242058314633E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 Bush Street
# 	Area:  1.4730834191850895E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Medical
# 	Address:  500 Parnassus Avenue
# 	Area:  0.0000010885411070165927
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 Bush Street
# 	Area:  1.4510719015195695E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  450 Powell Street
# 	Area:  9.631804152983101E-8
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  100 Montgomery Street
# 	Area:  1.9011083299994884E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  351 California Street
# 	Area:  8.15790826433906E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  220 Bush Street
# 	Area:  5.758359517321786E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  450 Sutter Street
# 	Area:  2.066937097893067E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  100 McAllister Street
# 	Area:  1.604931600195534E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  1101 Green Street
# 	Area:  3.656065814467177E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  235 Montgomery Street
# 	Area:  3.807070033652548E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  111 Sutter Street
# 	Area:  1.1951609065558987E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Residential
# 	Address:  1201 California Street
# 	Area:  9.941288452883456E-8
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Hotels, Visitor Services
# 	Address:  999 California Street
# 	Area:  3.29841972124275E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  140 New Montgomery Street
# 	Area:  1.1271734052987594E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  245 Market Street
# 	Area:  6.8729947279628E-7
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  225 Bush Street
# 	Area:  2.586341852508679E-7
# Building Name ['name']
# 	Structure type:  Steel Moment Frame
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  315 Montgomery Street
# 	Area:  1.2911623943093886E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 Market Street
# 	Area:  3.681045614811337E-7
# Building Name ['name']
# 	Structure type:  RC Shear Wall
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  1 Dr Carlton B Goodlett Place
# 	Area:  0.00000110110741263277
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  582 Market Street
# 	Area:  5.221581255097311E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  785 Market Street
# 	Area:  6.491899940303237E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Office (Management, Information, Professional Services)
# 	Address:  703 Market Street
# 	Area:  4.1683748222885044E-8
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Cultural, Institutional, Educational
# 	Address:  One Ferry Building
# 	Area:  0.0000010122205406330407
# Building Name ['name']
# 	Structure type:  Unknown
# 	Occupancy:  Residential
# 	Address:  690 Market Street
# 	Area:  1.09990766622742E-7

# %% [markdown]
# ### Excercise 2: Write the data from excercise 1 into a csv text file including latitude and longitude

# %%
import csv
with open('tallb.csv', 'w') as f:       
    write = csv.writer(f)        
    write.writerows(tallBuildings)

# %%
import csv

with open('tallb.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(row)
            line_count += 1
    print(f'Processed {line_count} lines.')

import pandas as pds
#dframe = pds.read_csv('tallb.csv')
#dframe

df = pds.to_csv(tallbuildings)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4960ab704770> in <module>
#       3 #dframe
#       4
# ----> 5 df = pds.to_csv(tallbuildings)
#       6 df
#
# C:\Anaconda\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %% [markdown]
# ### Exercise 3: Can we get PGA from USGS API for each building and include it in the output file

# %% [markdown]
# ## Part 3: "Selenium"
#
# For this part, you need to install an additional driver that depends upon your default web browser.
#
# * Main page: https://www.selenium.dev/
# * WebDriver (look for the **browser** section): https://www.selenium.dev/downloads/
#    * chrome: https://sites.google.com/a/chromium.org/chromedriver/
#    * safari: https://developer.apple.com/documentation/webkit/about_webdriver_for_safari
#    * edge: https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/#downloads
# * Selenium IDE:
#    * chrome: https://chrome.google.com/webstore/detail/selenium-ide/mooikfkahbdckldjjndioackbalphokd
#    * firefox: https://addons.mozilla.org/en-US/firefox/addon/selenium-ide/

# %% [markdown]
# Loading the supporting modules

# %%
import sys
import os
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup

# %%
#Starting the browser and opening tax assessor's data website for Anchorage
browser = webdriver.Chrome('./WebDriver') 
url = "https://www.muni.org/pw/public.html"
browser.get(url)

# %%
#Fill parcel search box with zero
parcelBox1 = browser.find_element_by_name("PAR1")
parcelBox1.send_keys('0')

#Click on Submit
submitButton = browser.find_element_by_name("submitbtn") 
submitButton.click()

# %%
for i in range(1,3):
    print("Processing results page {}".format(i))
    #Finding the parcels table with XPath
    parcelsTable = browser.find_elements_by_xpath("//table[1]/tbody/tr[2]/td/table[5]/tbody/tr")
    parcelsCount = len(parcelsTable)

    #Looping through the parcels table rows
    for i in range(1, parcelsCount):
        #extracting the parcel id
        parcelRow = browser.find_element_by_xpath("//table[1]/tbody/tr[2]/td/table[5]/tbody/tr[{}]".format(i+1))
        parcelIdCell = parcelRow.find_element_by_xpath(".//td[1]")
        if parcelIdCell is not None:
            parcelId = parcelIdCell.text
            
            #Clinking on the parcel to open the parcel details
            parcelIdCell.click()
            WebDriverWait(browser, 10)

            occupancy = 'unknown'
            #We can now parse the parcel details
            #e.g. let's find the occupancy
            try:
                parcelSoup = BeautifulSoup(browser.page_source, "html.parser")
                
                #We will assume the header is always the seventh table row (maybe using trial and error)
                parcelHeader = parcelSoup.findAll('tr')[7].text

                #We will read the header
                if('Residential' in parcelHeader):
                    occupancy = 'Residential'
                elif('Commercial' in parcelHeader):
                    occupancy = 'Commercial'

            except:
                "Error: Failed to process parcel: " + parcelId

            print("Parcel: {} is {}".format(parcelId, occupancy))

            #clicking on the back button
            backButton = browser.find_element_by_name("backbtn")
            backButton.click()
    #Going to next page in the search results       
    nextButton = browser.find_element_by_name("nextbtn")
    nextButton.click()

# %% [markdown]
# ### Excercise 4: Can we extract more information about these buildings
# e.g.
# * number of stories,
# * year built,
# * area
# * etc.

# %% [markdown]
# ### Excercise 5: Now let's do this for Washington State
#
# https://wa-geoservices.maps.arcgis.com/home/item.html?id=3dca0b72eae94c098b21329e1e61afd7
#
# Knowing I live in Washington State, how could you design a program to find my home address?

# %% [markdown]
# ## Further recommendations
#
# Here is the package for data mining from the web that I used earlier: https://github.com/clips/pattern
#
# Pattern is a web mining module for Python. It has tools for:
#
# * Data Mining: web services (Google, Twitter, Wikipedia), web crawler, HTML DOM parser
# * Natural Language Processing: part-of-speech taggers, n-gram search, sentiment analysis, WordNet
# * Machine Learning: vector space model, clustering, classification (KNN, SVM, Perceptron)
# * Network Analysis: graph centrality and visualization.
#
# It is well documented, thoroughly tested with 350+ unit tests and comes bundled with 50+ examples. The source code is licensed under BSD.
#
# <img src="https://raw.githubusercontent.com/clips/pattern/master/docs/g/pattern_schema.gif">

# %% [markdown]
# ## Visualizing geospatial data
#
# We recommend the **geopandas** library for easy visualization of GIS data.  You can find several easy to follow tutorials on youTube, e.g.,
# * [Introduction to Visualizing Geospatial Data with Python GeoPandas](https://www.youtube.com/watch?v=IdxL5NZ7h_c) (~30 mins)
# * [Introduction to Spatial Analysis in Python with Geopandas - Tutorial](https://www.youtube.com/watch?v=h5sy0z2BUTo) (~15 mins)

# %% [markdown]
# I am using example data files from th elatter video. Source: https://drive.google.com/drive/folders/1C_Zx4r-zRyc_9mNJ0XFZM4CDKuvtITaW

# %%
import geopandas as gpd
import matplotlib.pyplot as plt 
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Reading the world shapefile 
world_data = gpd.read_file('./GIS/Visualizing Geographical Data/world.shp')
world_data = world_data[['NAME', 'geometry']]

# Calculating the area of each country 
world_data['area'] = world_data.area

# Removing Antarctica from GeoPandas GeoDataframe
world_data = world_data[world_data['NAME'] != 'Antarctica']
world_data.plot()

# %% [markdown]
# #### Here with the recommended re-projection (see https://geopandas.org/projections.html#re-projecting)

# %%
world_data.to_crs(epsg=3395).plot()

# %%
# Changing the projection and adding color
current_crs = world_data.crs   
world_data.to_crs(epsg = 3857, inplace = True)
world_data.plot(column = 'NAME', cmap = 'hsv')

# %%
# Re-calculate the areas in Sq. Km.
world_data['area'] = world_data.area/1000000

# Adding a legend 
world_data.plot(column = 'area' , cmap = 'hsv' , legend = True, 
                legend_kwds = {'label': "Area of the country (Sq. Km.)"}, figsize = (7,7))

# %%
# Resizing the legend 
plt.clf
fig, ax = plt.subplots(figsize = (8,8))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size = "7%", pad = 0.1)

world_data.plot(column = 'area' , cmap = 'hsv' , legend = True,  
                legend_kwds = {'label': "Area of the country (Sq. Km.)"}, 
                ax = ax, cax = cax)

# %%
# %matplotlib inline

# %% [markdown]
# Plotting with Geoplot and GeoPandas
# -----------------------------------
#
# `Geoplot <https://residentmario.github.io/geoplot/index.html>`_ is a Python
# library providing a selection of easy-to-use geospatial visualizations. It is
# built on top of the lower-level `CartoPy <http://scitools.org.uk/cartopy/>`_,
# covered in a separate section of this tutorial, and is designed to work with
# GeoPandas input.
#
# This example is a brief tour of the `geoplot` API. For more details on the
# library refer to `its documentation
# <https://residentmario.github.io/geoplot/index.html>`_.
#
# First we'll load in the data using GeoPandas.

# %%
import geopandas
import geoplot

world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)
boroughs = geopandas.read_file(
    geoplot.datasets.get_path('nyc_boroughs')
)
collisions = geopandas.read_file(
    geoplot.datasets.get_path('nyc_injurious_collisions')
)

# %% [markdown]
# Plotting with Geoplot
# =====================
#
# We start out by replicating the basic GeoPandas world plot using Geoplot.

# %%
geoplot.polyplot(world, figsize=(8, 4))

# %% [markdown]
# Geoplot can re-project data into any of the map projections provided by
# CartoPy (see the list
# `here <http://scitools.org.uk/cartopy/docs/latest/crs/projections.html>`_).

# %%
# use the Orthographic map projection (e.g. a world globe)
ax = geoplot.polyplot(
    world, projection=geoplot.crs.Orthographic(), figsize=(8, 4)
)
ax.outline_patch.set_visible(True)

# %% [markdown]
# ``polyplot`` is trivial and can only plot the geometries you pass to it. If
# you want to use color as a visual variable, specify a ``choropleth``. Here
# we sort GDP per person by country into five buckets by color, using
# "quantiles" binning from the `Mapclassify <https://pysal.org/mapclassify/>`_
# library.

# %%
import mapclassify
gpd_per_person = world['gdp_md_est'] / world['pop_est']
scheme = mapclassify.Quantiles(gpd_per_person, k=5)

# Note: this code sample requires geoplot>=0.4.0.
geoplot.choropleth(
    world, hue=gpd_per_person, scheme=scheme,
    cmap='Greens', figsize=(8, 4)
)

# %% [markdown]
# If you want to use size as a visual variable, use a ``cartogram``. Here are
# population estimates for countries in Africa.

# %%
africa = world.query('continent == "Africa"')
ax = geoplot.cartogram(
    africa, scale='pop_est', limits=(0.2, 1),
    edgecolor='None', figsize=(7, 8)
)
geoplot.polyplot(africa, edgecolor='gray', ax=ax)

# %% [markdown]
# If we have data in the shape of points in space, we may generate a
# three-dimensional heatmap on it using ``kdeplot``.

# %%
ax = geoplot.kdeplot(
    collisions.head(1000), clip=boroughs.geometry,
    shade=True, cmap='Reds',
    projection=geoplot.crs.AlbersEqualArea())
geoplot.polyplot(boroughs, ax=ax, zorder=1)

# %% [markdown]
# Alternatively, we may partition the space into neighborhoods automatically,
# using Voronoi tessellation. This is a good way of visually verifying whether
# or not a certain data column is spatially correlated.

# %% [markdown]
# These are just some of the plots you can make with Geoplot. There are
# many other possibilities not covered in this brief introduction. For more
# examples, refer to the
# `Gallery <https://residentmario.github.io/geoplot/gallery/index.html>`_ in
# the Geoplot documentation.

# %% [markdown]
# ## Adding a background map to plots
#
# source: https://geopandas.org/gallery/plotting_basemap_background.html
#
# This example shows how you can add a background basemap to plots created
# with the geopandas ``.plot()`` method. This makes use of the
# `contextily <https://github.com/geopandas/contextily>`__ package to retrieve
# web map tiles from several sources (OpenStreetMap, Stamen).

# %%
import geopandas

###############################################################################
# Let's use the NYC borough boundary data that is available in geopandas
# datasets. Plotting this gives the following result:

df = geopandas.read_file(geopandas.datasets.get_path('nybb'))
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')

# %%
###############################################################################
# Convert the data to Web Mercator
# ================================
#
# Web map tiles are typically provided in
# `Web Mercator <https://en.wikipedia.org/wiki/Web_Mercator>`__
# (`EPSG 3857 <https://epsg.io/3857>`__), so we need to make sure to convert
# our data first to the same CRS to combine our polygons and background tiles
# in the same map:

df = df.to_crs(epsg=3857)

###############################################################################

import contextily as ctx

###############################################################################
# Add background tiles to plot
# ============================
#
# We can use `add_basemap` function of contextily to easily add a background
# map to our plot. :

ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax)

# %%
###############################################################################
# We can control the detail of the map tiles using the optional `zoom` keyword
# (be careful to not specify a too high `zoom` level,
# as this can result in a large download).:

ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax, zoom=12)

# %%
###############################################################################
# By default, contextily uses the Stamen Terrain style. We can specify a
# different style using ``ctx.providers``:

ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax, url=ctx.providers.Stamen.TonerLite)
ax.set_axis_off()
